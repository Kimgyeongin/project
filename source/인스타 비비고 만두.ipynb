# %%
import pandas as pd
import re
import numpy as np

# %%
df=pd.read_csv("../data/본문.csv")
df1=pd.read_csv('../data/해시태그.csv')
df2=pd.read_csv('../data/댓글.csv')

# %%
from konlpy.corpus import kolaw

# %%
from konlpy.tag import *

# %%
hannanum=Hannanum()
kkma=Kkma()
komoran=Komoran()
okt=Okt()
#komoran.nouns("\n".join([s for s in str(hash00_02).split("\n") if s]))

# %%
main=df["본문"]
hashtag=df1["해시태그"]
chat=df2["댓글"]
alldata=pd.concat([main, hashtag, chat])

# %%
len(alldata)
# Out:
# 11064

# %%
from konlpy.tag import Twitter
from collections import Counter

# %%
def strip_e(st):
    RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    return RE_EMOJI.sub(r'', st)

def get_tags(text, ntags=10000):
    #spliter = komoran
    #spliter = hannanum
    spliter = okt
    #spliter = kkma
    # konlpy의 Twitter객체
    nouns = spliter.nouns(text)
    #nouns = spliter.nouns("\n".join([s for s in text.split("\n") if s]))
    # nouns 함수를 통해서 text에서 명사만 분리/추출
    count = Counter(nouns)
    # Counter객체를 생성하고 참조변수 nouns할당
    return_list = []  # 명사 빈도수 저장할 변수
    for n, c in count.most_common(ntags):
        temp = {'tag': n, 'count': c}
        return_list.append(temp)
    # most_common 메소드는 정수를 입력받아 객체 안의 명사중 빈도수
    # 큰 명사부터 순서대로 입력받은 정수 갯수만큼 저장되어있는 객체 반환
    # 명사와 사용된 갯수를 return_list에 저장합니다.
    return return_list

# %%
main1=get_tags(strip_e(str(main)))

# %%
len((str(main)))
# Out:
# 3575

# %%
main2=pd.DataFrame(main1)
main2
# Out:
#      count   tag
# 0       17    만두
# 1       10   비비고
# 2        8    오늘
# 3        6    저녁
# 4        3    점심
# 5        3    쫄면
# 6        3    새해
# 7        3    분식
# 8        3     개
# 9        3    어묵
# 10       2    위해
# 11       2     집
# 12       2     전
# 13       2    먹기
# 14       2    아침
# 15       2   스카이
# 16       2    캐슬
# 17       2    맥주
# 18       2    남편
# 19       2    걱정
# 20       2     리
# 21       2    주말
# 22       2    우리
# 23       2    야식
# 24       2    어제
# 25       2    요즘
# 26       2    에어
# 27       2  프라이어
# 28       2    파뤼
# 29       2    낮잠
# ..     ...   ...
# 116      1    따리
# 117      1    달이
# 118      1    펑키
# 119      1  레츠파뤼
# 120      1   어젯밤
# 121      1   이야기
# 122      1     또
# 123      1    자고
# 124      1     푹
# 125      1    엽떡
# 126      1    동네
# 127      1    바퀴
# 128      1     후
# 129      1    타임
# 130      1     만
# 131      1    한섬
# 132      1    안주
# 133      1     듯
# 134      1    멸치
# 135      1    국물
# ...

# %%
hashtag1=get_tags(strip_e(str(hashtag)))
hashtag2=pd.DataFrame(hashtag1)
hashtag2
# Out:
#      count   tag
# 0       61    만두
# 1       49   비비고
# 2       11    스타
# 3       11    그램
# 4       10    집밥
# 5        6    저녁
# 6        5    점심
# 7        5    오늘
# 8        5     군
# 9        4     떡
# 10       4    에어
# 11       4    요리
# 12       4    일상
# 13       4    왕교
# 14       3    주말
# 15       3    홈쿡
# 16       3    쫄면
# 17       3    튀김
# 18       3  프라이어
# 19       3    한식
# 20       3    맥주
# 21       3    떡국
# 22       3    메뉴
# 23       3   만두국
# 24       3     맛
# 25       3   떡볶이
# 26       3    어묵
# 27       3   만둣국
# 28       2  비빔국수
# 29       2     김
# ..     ...   ...
# 181      1    사면
# 182      1    과학
# 183      1    재료
# 184      1    주방
# 185      1     점
# 186      1   브런치
# 187      1    추천
# 188      1    우리
# 189      1    부부
# 190      1    가사
# 191      1     법
# 192      1     윤
# 193      1    실장
# 194      1    주신
# 195      1   성애자
# 196      1     술
# 197      1    알콜
# 198      1    술상
# 199      1    역시
# 200      1    구들
# ...

# %%
chat1=get_tags(strip_e(str(chat)))
chat2=pd.DataFrame(chat1)
chat2
# Out:
#     count  tag
# 0       5   소통
# 1       5   만두
# 2       3   혼자
# 3       3   하루
# 4       3  비비고
# 5       2  돈까스
# 6       2    저
# 7       2   가요
# 8       2    전
# 9       2   짱구
# 10      2   아빠
# 11      2  중고차
# 12      2  최정진
# 13      2   페이
# 14      2   고객
# 15      2    후
# 16      2  반영구
# 17      2    제
# 18      2   사진
# 19      2   자주
# 20      2   피드
# 21      2   날씨
# 22      2   댓글
# 23      2   사랑
# 24      1    닌
# 25      1   헬스
# 26      1    왜
# 27      1  애벌레
# 28      1   저걸
# 29      1    민
# ..    ...  ...
# 70      1  페이지
# 71      1    놀
# 72      1    통
# 73      1   언니
# 74      1   메뉴
# 75      1   방법
# 76      1   점심
# 77      1  클리어
# 78      1   고향
# 79      1   역할
# 80      1   오늘
# 81      1    낮
# 82      1    밥
# 83      1   방가
# 84      1    용
# 85      1   맞팔
# 86      1   응원
# 87      1    인
# 88      1    쉿
# 89      1   감기
# 90      1   진짜
# 91      1    멋
# 92      1   여름
# 93      1   무지
# 94      1  꽃처럼
# 95      1   느낌
# ...

# %%
alldata1=get_tags(strip_e(str(alldata)), 100000)
alldata2=pd.DataFrame(alldata1)
alldata2.to_csv("all.csv",encoding="euc-kr", index=False)

# %%
alldata2
# Out:
#      count  tag
# 0        9   만두
# 1        6   오늘
# 2        4  비비고
# 3        4   소통
# 4        3   사진
# 5        2   저녁
# 6        2   쫄면
# 7        2    전
# 8        2  스카이
# 9        2   캐슬
# 10       2   혼자
# 11       2   자주
# 12       2   피드
# 13       2   하루
# 14       2   날씨
# 15       2   사랑
# 16       1   점심
# 17       1   리기
# 18       1   실습
# 19       1   주간
# 20       1   삼양
# 21       1   튀김
# 22       1   하나
# 23       1    수
# 24       1    의
# 25       1   보충
# 26       1   위해
# 27       1    치
# 28       1   그냥
# 29       1   오지
# ..     ...  ...
# 80       1   역할
# 81       1    낮
# 82       1    밥
# 83       1   방가
# 84       1    용
# 85       1   맞팔
# 86       1   응원
# 87       1    인
# 88       1    쉿
# 89       1   감기
# 90       1   진짜
# 91       1    멋
# 92       1   여름
# 93       1   무지
# 94       1  꽃처럼
# 95       1    제
# 96       1   느낌
# 97       1   댓글
# 98       1    달
# 99       1   가요
# 100      1  팔로우
# 101      1   짱구
# 102      1   아빠
# ...
