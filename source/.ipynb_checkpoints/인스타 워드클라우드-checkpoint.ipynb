# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import platform
from matplotlib import font_manager, rc
if platform.system()=='Windows':
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:
    rc('font', family='AppleGothic')
from wordcloud import WordCloud, STOPWORDS
import nltk


from konlpy.tag import Twitter; t = Twitter()
# Out:
# C:\Users\OliviaKim\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
import pandas as pd

# %%
food01=pd.read_csv("../data/food01.csv")
kind02=pd.read_csv("../data/kind02.csv")
nick03=pd.read_csv("../data/nick03.csv")
when06=pd.read_csv("../data/when06.csv")
where05=pd.read_csv("../data/where05.csv")

# %%
food=list(food01.itertuples(index=False, name=False))
kind=list(kind02.itertuples(index=False, name=False))
nick=list(nick03.itertuples(index=False, name=False))
when=list(when06.itertuples(index=False, name=False))
where=list(where05.itertuples(index=False, name=False))

# %%
where
# Out:
# [('요리', 527),
#  ('집밥', 412),
#  ('간식', 266),
#  ('홈쿡', 132),
#  ('안주', 106),
#  ('분식', 95),
#  ('저녁밥', 63),
#  ('파김치', 31),
#  ('모두', 31),
#  ('구', 31),
#  ('갑자기', 31),
#  ('간단', 31),
#  ('양념', 31),
#  ('김치볶음밥', 31),
#  ('토요일', 31),
#  ('골뱅이', 31),
#  ('마늘', 31),
#  ('욤', 31),
#  ('꼬막', 31),
#  ('신상', 31),
#  ('순이', 31),
#  ('데이', 30),
#  ('번', 30),
#  ('간', 30),
#  ('꽃', 30),
#  ('캔', 30),
#  ('듀', 30),
#  ('닭발', 30),
#  ('듬뿍', 30),
#  ('건강', 30),
#  ('글', 30),
#  ('욧', 29),
#  ('신라면', 29),
#  ('김치전', 29),
#  ('니', 29),
#  ('맛점', 29),
#  ('휴일', 29),
#  ('양파', 29),
#  ('보기', 29),
#  ('어머', 29),
#  ('아침밥', 29),
#  ('대구', 29),
#  ('앞', 28),
#  ('부업', 28),
#  ('칼로리', 28),
#  ('신제품', 28),
#  ('피자', 28),
#  ('정보', 28),
#  ('왕', 28),
#  ('후식', 28),
#  ('성공', 28),
#  ('가루', 28),
#  ('분위기', 28),
#  ('아스타', 28),
#  ('데이트', 28),
#  ('동생', 27),
#  ('프라이', 27),
#  ('비쥬', 27),
#  ('오픈', 27),
#  ('무', 27),
#  ('기', 27),
#  ('통', 27),
#  ('방', 27),
#  ('살이', 27),
#  ('오뚜기', 27),
#  ('중국', 27),
# ...

# %%
alice_coloring = np.array(Image.open("../data/alice2.png"))
dumpling=np.array(Image.open("../data/dumpling.jpeg"))
dump1=np.array(Image.open("../data/dump.jpg"))
kind_image=np.array(Image.open("../data/noodles1.jpeg"))
nick_image=np.array(Image.open("../data/head-icon-6532.png"))
when_image=np.array(Image.open("../data/hourglass.png"))
where_image=np.array(Image.open("../data/where4.jpeg"))
cj_image=np.array(Image.open("../data/cjlogo.png"))
bibigo_image=np.array(Image.open("../data/bibigo.png"))
time_image=np.array(Image.open("../data/time2.png"))
food_image=np.array(Image.open("../data/dishcap.jpeg"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-983785d8a943> in <module>()
#       2 dumpling=np.array(Image.open("../data/dumpling.jpeg"))
#       3 dump1=np.array(Image.open("../data/dump.jpg"))
# ----> 4 kind_image=np.array(Image.open("../data/noodles1.jpeg"))
#       5 nick_image=np.array(Image.open("../data/head-icon-6532.png"))
#       6 when_image=np.array(Image.open("../data/hourglass.png"))
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2475
#    2476     if filename:
# -> 2477         fp = builtins.open(filename, "rb")
#    2478         exclusive_fp = True
#    2479
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/noodles1.jpeg'

# %%
when_image=np.array(Image.open("../data/hourglass.png"))

# %%
from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(alice_coloring)
image_colors1=ImageColorGenerator(dump1)
image_colors2=ImageColorGenerator(cj_image)
image_colors3=ImageColorGenerator(bibigo_image)

# %%
from wordcloud import ImageColorGenerator
fontpath = 'C:/Windows/Fonts/Jalnan_1.ttf'

# %%
#만두(all color)
dumpling1 = np.array(Image.open("../data/jpg_icon/만두/만두1.jpg"))
dumpling2 = np.array(Image.open("../data/jpg_icon/만두/만두2.jpg"))
dumpling3 = np.array(Image.open("../data/jpg_icon/만두/만두3.jpg"))

# %%
plt.imshow(dumpling3)

# %%
#시간(color: time2)
time1=np.array(Image.open("../data/jpg_icon/시간/모래시계1.jpg"))
time2=np.array(Image.open("../data/jpg_icon/시간/모래시계2.jpg"))

#ImageColorGenerator
time2_colors=ImageColorGenerator(time2)

# %%
#요리(color: cook2)
cook1=np.array(Image.open("../data/jpg_icon/요리/요리사1.jpg"))
cook2=np.array(Image.open("../data/jpg_icon/요리/요리사2.jpg"))
cook3=np.array(Image.open("../data/jpg_icon/요리/요리사3.jpg"))
cook4=np.array(Image.open("../data/jpg_icon/요리/요리사4.jpg"))

# %%
#요리방법(color : cookware3, cookware4)
cookware1=np.array(Image.open("../data/jpg_icon/요리방법/조리도구1.jpg"))
cookware2=np.array(Image.open("../data/jpg_icon/요리방법/조리도구2.jpg"))
cookware3=np.array(Image.open("../data/jpg_icon/요리방법/조리도구3.jpg"))
cookware4=np.array(Image.open("../data/jpg_icon/요리방법/조리도구4.jpg"))

# %%
#음료(color : beverage2, beverage3, beverage5)
beverage1=np.array(Image.open("../data/jpg_icon/음료/맥주1.jpg"))
beverage2=np.array(Image.open("../data/jpg_icon/음료/맥주2.jpg"))
beverage3=np.array(Image.open("../data/jpg_icon/음료/맥주3.jpg"))
beverage4=np.array(Image.open("../data/jpg_icon/음료/음료1.jpg"))
beverage5=np.array(Image.open("../data/jpg_icon/음료/콜라1.jpg"))

# %%
#음식( no color)
plate1=np.array(Image.open("../data/jpg_icon/음식/접시1.jpg"))
plate2=np.array(Image.open("../data/jpg_icon/음식/접시2.jpg"))

# %%
#장소(color : place1, place4)
place1=np.array(Image.open("../data/jpg_icon/장소/음식점1.jpg"))
place2=np.array(Image.open("../data/jpg_icon/장소/음식점2.jpg"))
place3=np.array(Image.open("../data/jpg_icon/장소/집1.jpg"))
place4=np.array(Image.open("../data/jpg_icon/장소/집2.jpg"))

# %%
#호칭(color : name3)
name1=np.array(Image.open("../data/jpg_icon/호칭/가족1.jpg"))
name2=np.array(Image.open("../data/jpg_icon/호칭/가족2.jpg"))
name3=np.array(Image.open("../data/jpg_icon/호칭/가족3.jpg"))
name4=np.array(Image.open("../data/jpg_icon/호칭/사람들1.jpg"))

# %%
#같이 먹는 음식
wc=WordCloud(background_color="white", max_words=2000,font_path=fontpath, mask=cj_image)
wc=wc.generate_from_frequencies(dict(food))
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=image_colors2), interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#같이 먹는 음식
wc=WordCloud(background_color="white", max_words=2000,font_path=fontpath, mask=dumpling3)
wc=wc.generate_from_frequencies(dict(food))
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=dumpling3_colors), interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#요리방법
wc=WordCloud(background_color="white",font_path=fontpath, mask=cookware1, max_font_size=50)
wc=wc.generate_from_frequencies(dict(kind))
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation="bilinear")
#plt.imshow(wc.recolor(color_func=cookware3_colors), interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#호칭
wc=WordCloud(background_color="white", max_words=2000,font_path=fontpath, mask=nick_image)
wc=wc.generate_from_frequencies(dict(nick))
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=), interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#where05
wc=WordCloud(background_color="white", max_words=2000,font_path=fontpath, mask=where_image, max_font_size=50)
wc=wc.generate_from_frequencies(dict(where))
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#when06
wc=WordCloud(background_color="white", max_words=2000,font_path=fontpath, mask=when_image, max_font_size=90)
wc=wc.generate_from_frequencies(dict(when))
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#"text" file has to be a list of tuples.
def make_imagecoloredwc(text, mask_image):
    wc = WordCloud(background_color="white", max_words=2000,font_path='C:/Windows/Fonts/Jalnan_1.ttf', mask=mask_image, max_font_size=90)
    # generate word cloud
    wc=wc.generate_from_frequencies(dict(text))
    f = plt.figure(figsize=(12, 12))
    plt.imshow(wc.recolor(color_func=ImageColorGenerator(img_matrix)), interpolation="bilinear")
    plt.axis("off")


def make_wc(text, mask_image, color):
    wc = WordCloud(background_color="white", max_words=2000,font_path='C:/Windows/Fonts/Jalnan_1.ttf', mask=mask_image, max_font_size=90,
                  colormap=color)
    # generate word cloud
    wc=wc.generate_from_frequencies(dict(text))
    f = plt.figure(figsize=(12, 12))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")

    
cmaps=['viridis', 'plasma', 'inferno', 'magma', 'cividis','Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 
       'Reds','YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu','GnBu', 'PuBu', 'YlGnBu', 
       'PuBuGn', 'BuGn', 'YlGn','binary','gist_yarg', 'gist_gray', 'gray', 'bone', 'pink','spring', 
       'summer', 'autumn', 'winter', 'cool', 'Wistia', 'hot','afmhot', 'gist_heat', 'copper','PiYG', 
       'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu','RdYlBu', 'RdYlGn', 'Spectral','coolwarm', 'bwr', 
       'seismic','hsv','Pastel1', 'Pastel2', 'Paired', 'Accent','Dark2', 'Set1', 
       'Set2', 'Set3','tab10', 'tab20', 'tab20b', 'tab20c','flag', 'prism', 'ocean', 'gist_earth', 
       'terrain', 'gist_stern', 'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg','gist_rainbow', 'rainbow', 'jet', 
       'nipy_spectral', 'gist_ncar']

# %%
make_wc(when, when_image,cmaps[2])
cmaps[2]
# Out:
# 'inferno'

# %%
len(cmaps)
# Out:
# 82
