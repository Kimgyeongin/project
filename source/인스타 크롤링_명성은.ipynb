# %%
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
import platform
import re
from urllib.request import urlopen
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
   rc('font', family='AppleGothic')
elif platform.system() == 'Windows'    :
   path = "c:/Windows/Fonts/malgun.ttf"
   font_name = font_manager.FontProperties(fname=path).get_name()
   rc('font', family=font_name)
else:
   print('Unknown system')

plt.rcParams['axes.unicode_minus'] = False

# %%
# Out:
# 2217

# %%
#1 주소 가져오기
driver= webdriver.Chrome('../driver/chromedriver')
#driver.get('https://www.instagram.com/explore/tags/%EB%B9%84%EB%B9%84%EA%B3%A0%EB%A7%8C%EB%91%90/')  #사이트주소
driver.get("https://www.instagram.com/explore/tags/%EB%B9%84%EB%B9%84%EA%B3%A0%EC%99%95%EA%B5%90%EC%9E%90/")
ubox = []
cbox = [1,2,3,4]



page1 = driver.page_source
soup1 = BeautifulSoup(page1)
a2 = soup1.find_all('div',"Nnq7C weEfm")
for i in range(0,len(a2)):
    bb1 = a2[i].find_all('a')[0]['href']
    bb2 = a2[i].find_all('a')[1]['href']
    bb3 = a2[i].find_all('a')[2]['href']
    ubox.append(bb1)
    ubox.append(bb2)
    ubox.append(bb3)
    
ubox = list(set(ubox))
y=500
while len(ubox) < 10000:

    if len(ubox) > len(cbox):
        page1 = driver.page_source
        soup1 = BeautifulSoup(page1)
        a2 = soup1.find_all('div',"Nnq7C weEfm")
        for i in range(0,len(a2)):
            bb1 = a2[i].find_all('a')[0]['href']
            bb2 = a2[i].find_all('a')[1]['href']
            bb3 = a2[i].find_all('a')[2]['href']
            ubox.append(bb1)
            ubox.append(bb2)
            ubox.append(bb3)
        ubox = list(set(ubox))
        cbox=ubox

    else:
        time.sleep(1)
        y=200+y
        c= 10000+y
        driver.execute_script("window.scrollTo(0, %s)"% c) 
        page1 = driver.page_source
        soup1 = BeautifulSoup(page1)
        a2 = soup1.find_all('div',"Nnq7C weEfm")
        for i in range(0,len(a2)):
            bb1 = a2[i].find_all('a')[0]['href']
            bb2 = a2[i].find_all('a')[1]['href']
            bb3 = a2[i].find_all('a')[2]['href']
            ubox.append(bb1)
            ubox.append(bb2)
            ubox.append(bb3)
        ubox = list(set(ubox))
        cbox=ubox
        
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
# Out:
# C:\Users\OliviaKim\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\OliviaKim\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-5099e64e7381> in <module>()
#      38
#      39     else:
# ---> 40         time.sleep(2)
#      41         y=100+y
#      42         c= 10000+y
#
# KeyboardInterrupt:

# %%
len(ubox)
# Out:
# 2919

# %%
kkk=pd.DataFrame(ubox)
kkk.to_csv("ubox.csv", index=False)

# %%
ubox
# Out:
# ['/p/Bsarnjig7hZ/',
#  '/p/Buqt6_lnPBK/',
#  '/p/Bt3SksLBtIW/',
#  '/p/BxjD2lSn8cz/',
#  '/p/Bw3X3rihhaW/',
#  '/p/By6lZp-lMjt/',
#  '/p/BwQuMi8BlXQ/',
#  '/p/BsmoPQOAajS/',
#  '/p/ByR70J4A12U/',
#  '/p/Br46iwZg-q6/',
#  '/p/BruoPxNgiqO/',
#  '/p/BvZIJ68Fc8r/',
#  '/p/ByRAzDHH9K_/',
#  '/p/Bt-FWQCh83j/',
#  '/p/BxpMagMBJFG/',
#  '/p/BtsupuNFF_x/',
#  '/p/BtKrTwFnzxn/',
#  '/p/BrhhBM5h4tn/',
#  '/p/Bsb6oG4glnt/',
#  '/p/BtqYv3kgX_Z/',
#  '/p/Brsl1w4grC1/',
#  '/p/BzC24TFpXUg/',
#  '/p/BrptmWPgk2B/',
#  '/p/ByRpLLPppm6/',
#  '/p/BxzUXNdnPex/',
#  '/p/Bui5gqsFuG4/',
#  '/p/BzCZk-JBIao/',
#  '/p/BxXcTLqFtZS/',
#  '/p/Bwjo4PvBjzy/',
#  '/p/BvT_YDHA8-X/',
#  '/p/BrjmsvAAbic/',
#  '/p/Br41gDkni2G/',
#  '/p/BtI_nSuBlKi/',
#  '/p/BraEo8zgJwQ/',
#  '/p/BsvOb6RB0lP/',
#  '/p/Bxm2alaBYsA/',
#  '/p/BuYaFvIjCJ9/',
#  '/p/BwMGZkPl6Rx/',
#  '/p/BwUQBYDnYzJ/',
#  '/p/BucgwA9ljHh/',
#  '/p/Bt4RMGqlrzu/',
#  '/p/ByISTaMJHiT/',
#  '/p/BycBToWHn0y/',
#  '/p/BwT4iDRBTGR/',
#  '/p/BwgZCtMg8G7/',
# ...

# %%
kkk[0].tolist()
# Out:
# ['/p/Bsarnjig7hZ/',
#  '/p/Buqt6_lnPBK/',
#  '/p/Bt3SksLBtIW/',
#  '/p/BxjD2lSn8cz/',
#  '/p/Bw3X3rihhaW/',
#  '/p/By6lZp-lMjt/',
#  '/p/BwQuMi8BlXQ/',
#  '/p/BsmoPQOAajS/',
#  '/p/ByR70J4A12U/',
#  '/p/Br46iwZg-q6/',
#  '/p/BruoPxNgiqO/',
#  '/p/BvZIJ68Fc8r/',
#  '/p/ByRAzDHH9K_/',
#  '/p/Bt-FWQCh83j/',
#  '/p/BxpMagMBJFG/',
#  '/p/BtsupuNFF_x/',
#  '/p/BtKrTwFnzxn/',
#  '/p/BrhhBM5h4tn/',
#  '/p/Bsb6oG4glnt/',
#  '/p/BtqYv3kgX_Z/',
#  '/p/Brsl1w4grC1/',
#  '/p/BzC24TFpXUg/',
#  '/p/BrptmWPgk2B/',
#  '/p/ByRpLLPppm6/',
#  '/p/BxzUXNdnPex/',
#  '/p/Bui5gqsFuG4/',
#  '/p/BzCZk-JBIao/',
#  '/p/BxXcTLqFtZS/',
#  '/p/Bwjo4PvBjzy/',
#  '/p/BvT_YDHA8-X/',
#  '/p/BrjmsvAAbic/',
#  '/p/Br41gDkni2G/',
#  '/p/BtI_nSuBlKi/',
#  '/p/BraEo8zgJwQ/',
#  '/p/BsvOb6RB0lP/',
#  '/p/Bxm2alaBYsA/',
#  '/p/BuYaFvIjCJ9/',
#  '/p/BwMGZkPl6Rx/',
#  '/p/BwUQBYDnYzJ/',
#  '/p/BucgwA9ljHh/',
#  '/p/Bt4RMGqlrzu/',
#  '/p/ByISTaMJHiT/',
#  '/p/BycBToWHn0y/',
#  '/p/BwT4iDRBTGR/',
#  '/p/BwgZCtMg8G7/',
# ...

# %%
#댓글 본문 해쉭택 가져오기
#for i in range(0,len(ubox))
driver= webdriver.Chrome('../driver/chromedriver')
box1 = []
box2 = []
box3 = []
box4 = []
box5= []
for i in range(0,len(ubox)):
#for i in range(0,100):
    a = ubox[i]
    a = 'https://www.instagram.com'+a
    try:
        driver.get(a)  #사이트주소
        page1 = driver.page_source
        soup1 = BeautifulSoup(page1)
        a = soup1.find_all('div','C4VMK')
        a1 = soup1.find_all('div','C4VMK')[0]
        a1 = a1.find_all('span')[0].text
        b1 = re.split('#',a1)[0]
        b2 = re.split('#',a1)[1:]
        c = soup1.find_all('time')[0]['datetime']
        #c1 = re.split('[:]+', c)[0]
        #c2=re.split('T', c1)[1]
        box1.append(b1)
        box2.append(b2)
        box4.append(c)
        for i in range(1,len(a)):
            a2 = soup1.find_all('div','C4VMK')[i]
            a2 = a2.find_all('span')[0].text
            box3.append(a2)
            box5.append(c)
    except:
        pass
        
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
print('ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd')
# Out:
# C:\Users\OliviaKim\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\OliviaKim\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd
# ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd
# ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd
# ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd
# ddddddddddddddddddddddddddddddddddddddddddddddddddddddddddd

# %%
page1 = driver.page_source
soup1 = BeautifulSoup(page1)
a = soup1.find_all('time')[0]['datetime']
a
# Out:
# '2019-04-16T20:28:34.000Z'

# %%
c1 = re.split('[:]+', c)[0]
c1
c2=re.split('T', c1)[1]
c2
# Out:
# '2019-02-04'

# %%
len(box5)
# Out:
# 8738

# %%
df = pd.DataFrame()
df["본문"]=box1
df["시간"]=box4
df1=pd.DataFrame()
df1["해시태그"]=box2
df1["시간"]=box4
df2=pd.DataFrame()
df2["댓글"]=box3
df2["시간"]=box5

# %%
#댓글
s1=[]
s2=[]
s3=[]
h1=[]
for i in range(0,len(df2)):
    s=re.split('[:]+', df2["시간"][i])[0]
    s1.append(s)
    s=re.split("T", s1[i])[1]
    s2.append(s)
    k=re.split("T", s1[i])[0]
    s3.append(k)
    h=re.split("-", s3[i])
    h1.append(h)
hh= pd.DataFrame(h1)
hh.columns = ['년', '월','일']
df2_2=pd.concat([df2, hh], axis=1)
df2_2["시"]=s2

# %%
df2_2
# Out:
#                                                      댓글  \
# 0                                    안녕하세요~^^소통해도 될까요?💓
# 1                                              안녕하세요 :)
# 2                             오동통한 소세지에 군만두👍먹음직스러워용!!♥️
# 3                                         마시께따아~~~~~~~😭
# 4                                                   👍👍👍
# 5                                                 출장와영😍
# 6                                        신부수업이여?ㅎㅎ금손이다으
# 7                     필라이트 가성비갑👍👍👍 그래도 초록이가 난 좀더 나은듯 ㅋㅋ
# 8                 그치그치! 에어프라이어는 만두지! 코끼리 한번먹기시작하믄ㅡㅡ못끊지ㅋ
# 9     ㅋㅋㅋㅋ필라이트는 정말 가성비갑인것 같아용!ㅎㅎ 프레시보단 원조가 더 맛있는 것 같...
# 10                                          Nice Photo~
# 11                                                    〰
# 12                                                    💛
# 13                                                   ❤️
# 14    문.의.수.익이 아직없으신가요?😞손소통 팔로워 매크로는  이제그만🤚수희에게 ⭕무료 ...
# 15                                너무 맛있어 보이니 배가 고파지네요ㅎㅎ
# ...

# %%
#본문&해시태그
s1=[]
s2=[]
s3=[]
h1=[]
for i in range(0,len(df1)):
    s=re.split('[:]+', df1["시간"][i])[0]
    s1.append(s)
    s=re.split("T", s1[i])[1]
    s2.append(s)
    k=re.split("T", s1[i])[0]
    s3.append(k)
    h=re.split("-", s3[i])
    h1.append(h)
hh= pd.DataFrame(h1)
hh.columns = ['년', '월','일']
df_2=pd.concat([df, hh], axis=1)
df_2["시"]=s2
df1_2=pd.concat([df1, hh], axis=1)
df1_2["시"]=s2

# %%
df1_2
# Out:
#                                                    해시태그  \
# 0     [오늘의야식 , 신랑이랑쨘쨘 , 집술 , 맥주안주 , 존쿡델리미트 , 이탈리안소시지...
# 1     [비빔만두, 비비고왕교자, 참나물, , , , , , , , , ..티비보다 우리아...
# 2     [워킹맘그램👠💄👜 , 힘든하루, 고생했어 , 정은씨 , 에어프라이어, 코끼리 , 비...
# 3                                           [만두는비비고가진리]
# 4                                  [비비고왕교자 , 엄마김치, 불고기]
# 5                       [요즘너무맛있는, 비비고왕교자 , 진짝존맛탱⠀⠀⠀⠀⠀⠀]
# 6              [비비고왕교자 고기&김치 만두! 간단한 아침겸점심 feat)에어프라이어]
# 7     [월요일 , 점심, 첫끼미세먼지 매우나쁨으로또 강제집순이😭😭도저히 먹을게 없어서비비...
# 8     [트란지아 , trangia , 손잡이반합 , mestin , メスティン , 찜기 ...
# 9     [짬뽕 에 몰타에서 사 온 팽이버섯도 올리고, 마지막 , 비비고왕교자 까지 클리어:...
# 10    [저녁 , 저녁메뉴 , 라면 , 라면스타그램 , 꼬들꼬들 , 농심 , 안성탕면 , ...
# 11    [첫줄오늘은 하루종일 요 한 끼로 식사 끝ㅋㅋㅋ삼양 열무 비빔면에 비비고 왕교자 3...
# 12    [아침 , 먹스타그램 , 비비고왕교자 , 군만두 , 겉바속촉 , 졸맛탱 , 만두 ,...
# 13    [짜파게티 , 하트딸기, 🍓 , 비비고왕교자챈공주가 짜파게티 먹는데서, 오늘은, 간...
# 14    [영니랑그램💞🙈좋아하는것들만😋먹다가갑자기, 정전 ! 혼자있었음 무서웠을뻔해찌만😱초키...
# 15    [짜장면 , 중국집 , 비비고왕교자 , 만두 , 양파 , 일요일 , 저녁 , 주말,...
# ...

# %%
df_2["d"]=np.where(df_2["시"].isin(["00","01","02","03","04","18","19","20","21","22","23"]),1,0)
df1_2["d"]=np.where(df1_2["시"].isin(["00","01","02","03","04","18","19","20","21","22","23"]),1,0)
df2_2["d"]=np.where(df2_2["시"].isin(["00","01","02","03","04","18","19","20","21","22","23"]),1,0)

# %%
df_2.to_csv("본문왕교자.csv",index=False,)
df1_2.to_csv("해시태그왕교자.csv", index=False)
df2_2.to_csv("댓글왕교자.csv", index=False)

# %%
df2_2
# Out:
#                                                      댓글  \
# 0                                    안녕하세요~^^소통해도 될까요?💓
# 1                                              안녕하세요 :)
# 2                             오동통한 소세지에 군만두👍먹음직스러워용!!♥️
# 3                                         마시께따아~~~~~~~😭
# 4                                                   👍👍👍
# 5                                                 출장와영😍
# 6                                        신부수업이여?ㅎㅎ금손이다으
# 7                     필라이트 가성비갑👍👍👍 그래도 초록이가 난 좀더 나은듯 ㅋㅋ
# 8                 그치그치! 에어프라이어는 만두지! 코끼리 한번먹기시작하믄ㅡㅡ못끊지ㅋ
# 9     ㅋㅋㅋㅋ필라이트는 정말 가성비갑인것 같아용!ㅎㅎ 프레시보단 원조가 더 맛있는 것 같...
# 10                                          Nice Photo~
# 11                                                    〰
# 12                                                    💛
# 13                                                   ❤️
# 14    문.의.수.익이 아직없으신가요?😞손소통 팔로워 매크로는  이제그만🤚수희에게 ⭕무료 ...
# 15                                너무 맛있어 보이니 배가 고파지네요ㅎㅎ
# ...

# %%
af1 = pd.DataFrame({'본문':df_2['본문']})
af2 = pd.DataFrame({'해시태그':df1_2['해시태그']})
af3 = pd.DataFrame({'댓글':df2_2['댓글']})

# %%
af = pd.concat([af1,af2,af3])
# Out:
# C:\Users\A\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
af1.to_csv("본문.txt", index=False)
af2.to_csv("해시태그.txt", index=False)
af3.to_csv("댓글.txt", index=False)
af.to_csv("합.txt", index=False)

# %%
import pandas as pd
a1 = str(box1)
a2 = str(box2)
a3 = str(box3)
a1
# Out:
# '[\'\', \'\', \'부부의날👫💕5월21일가정의달5월2(둘)이만나1(하나)가된날👍..\', \'\', \'\', \'섭이형네 집에서 게이트 ㅋㅋㅋㅋㅋ\', \'\', \'달콤모임 떡볶이🐷🐷당면사리 라면사리 청양고추 양배추 깻잎까지 넣어서 먹었더니 배 찢어질뻔😀😀..\', \'민짱표 떡만둣국.한살 더 먹었다.냠냠!..\', \'\', \'\', \'야식 지대로 뿌시고, 몸무게 확 늘리고여자는평생 다이어트 중인데... 저도 지금다이어트 중 입니다😟멈출수없는 사리 추가 ..\', \'아,,든든하다 🤤\', \'엄청 큰 비비고 만두\\U0001f95f \', \'\', \'만두러버😍😍 \', \'최애안주 🍻 \', \'\', \'\', \'나이 먹는 국! ㅋ한살 잘 먹겠습니다.\', \'\', \'진짜 믿고 먹는 비비고👩🏻\\u200d🍳❣️한섬만두&버섯칼국수 진짜 대에에에박\\U0001f970\\U0001f970\\U0001f970\\U0001f970\\U0001f970....\', \'\', \'떡만두국 만들기❣️우려낸 사골육수에 소고기듬뿍~~..\', \'저녁 스킵하고 맥주나 한 잔 하자고 했는데... \', \'\', \'\', \'⠀⠀⠀⠀⠀⠀⠀⠀아점저 한번에 먹기..ㅎ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀\', \'제가만든 라멘이에용 😘😘 물론 편의점에서 사왔지만 요리하는 느낌으루 냄비에 😛 오늘은 좀멀리가서 운동했는디 호두과자를 사고싶더라구요 동네를 벗어나서 그릉가 ㅋㅋ 저 내일은 서울가요 ^^ 오늘밤에 모든업무 끝내구 하루는 서울일정잘마치구 돌아올께요옹 🌹🌹🌹뭐먹지 서울가서🙏\', \'2019.05.23 목요일..아침엔 목요일이라 넘나리 행복했고오후는 넘나리 힘들어서 신랑한테 😭😭징징집에 있는 안주로 신랑이랑 한잔하는중~..\', \'.야식 \', \'귀찮은 주말엔 역시 \', \'\', \'되는 라인은 확실히 틀려요보세요~🤷\\u200d♀️🤷\\u200d♀️🤷\\u200d♀️🤷\\u200d♀️🤷\\u200d♀️
# ...

# %%
adf = pd.DataFrame({'noun':box3})

# %%
adf.head()
# Out:
#                                                 noun
# 0                     우와 ㅎㅎ 피드보니 맘에 들어서 ㅎㅎ 우리 인친해용 ~
# 1                                          소통할까요?^_^
# 2  수산물 온라인 쇼핑몰 바다의 품격입니다. 싱싱한 통영 산지직송 수산물로 식탁을 풍성...
# 3     이상하게 애낳고 맥주가 미친듯이 좋아;;;니 신랑 넘 낭만적이다야 다 챙기네~^^^
# 4                                            👍👍👍👍👍👍😍

# %%
adf.to_csv('out.txt', encoding='utf-8', index=False)
