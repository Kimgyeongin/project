# %%
import pandas as pd
import re
import numpy as np

# %%
df=pd.read_csv("본문왕교자.csv")
df1=pd.read_csv('해시태그왕교자.csv')
df2=pd.read_csv('댓글왕교자.csv')

# %%
main=df["본문"]
hashtag=df1["해시태그"]
chat=df2["댓글"]
alldata=pd.concat([main, hashtag, chat])

# %%
str(alldata)
# Out:
# '0                                                     NaN\n1                   이쁘고 비싼집사주면뭐하나코스트코에서 물건담아온 만두박스만좋아하는데🐱\n2                              미나리 , 청양 팍팍 넣고 떡만두매운탕 🍲🍲**\n3                                                     NaN\n4                                                     NaN\n5                                                     NaN\n6                                                     NaN\n7                                --토요일부터 나 없이 고생할 떠히를 위해 \n8                               직접 만들었다 누가? 내가 하하하오늘은 내가 \n9                                               .즐거운 저녁? \n10      비비고왕교자, 네모 군만두밥먹긴 뭐하고 배는 허전하고...😫만두나 굽자해서 버터어 ...\n11                                                    NaN\n12                                     꿀비가 해주는 오늘의 야식 \U0001f95f🍽 \n13                                                    NaN\n14                  불토~비비고 만두 다 태웠다.😭힝ㅋ 집에 있는것도 서러운데..😫..\n15      자정이 넘은 시각에 고구마x김치 콜라보로 슬슬 시동을 걸더니 비비고 왕교자까지 야무...\n16      ...비오는날 캠핑대신~은지가 협찬해준 겁나 매운 쭈꾸미찡오반장 
# ...

# %%
from konlpy.corpus import kolaw

# %%
from konlpy.tag import *
hannanum=Hannanum()
kkma=Kkma()
komoran=Komoran()
okt=Okt()

# %%
from konlpy.tag import Twitter
from collections import Counter

# %%
twitter = Twitter()
# Out:
# C:\Users\OliviaKim\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
def strip_e(st):
    RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    return RE_EMOJI.sub(r'', st)

# %%
len(str(alldata))
# Out:
# 3565

# %%
main_nouns=okt.morphs(strip_e(str(main)))

# %%
len(main_nouns)
# Out:
# 639

# %%
hashtag_noun=okt.morphs(strip_e(str(hashtag)))

# %%
chat_noun=okt.morphs(strip_e(str(chat)))

# %%
print(len(main_nouns))
print(len(hashtag_noun))
print(len(chat_noun))
# Out:
# 639
# 1289
# 544

# %%
nouns=hannanum.nouns(strip_e(str(alldata)))

# %%
nouns
# Out:
# ['0',
#  '1',
#  '비싼집사주면뭐하나코스트코',
#  '물건담아온',
#  '만두박스만좋아하는데',
#  '2',
#  '미나리',
#  '청양',
#  '떡만두매운탕',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '토요일',
#  '나',
#  '고생',
#  '떠히',
#  '8',
#  '누구',
#  '나',
#  '하하하오늘',
#  '나',
#  '9',
#  '저녁',
#  '10',
#  '비비고왕교자,',
#  '네모',
#  '군만두밥먹긴',
#  '뭐',
#  '허전',
#  '만두',
#  '굽자해서',
#  '버터',
#  '11',
#  '12',
#  '꿀비',
#  '오늘',
#  '야식',
#  '13',
#  '14',
#  '불토',
#  '비비',
#  '만두',
#  '힝ㅋ',
#  '집',
#  '것',
#  '데',
#  '15',
#  '자정',
#  '시각',
#  '고구마x김치',
#  '콜라보',
#  '시동',
#  '왕교자까지',
#  '야무',
#  '16',
#  '비오는날',
#  '캠핑대신~은지',
#  '협찬',
#  '겁',
#  '쭈꾸미찡오반장',
#  'jmt막창',
#  '에프',
#  '17',
#  '•새로운',
#  '라면',
#  '아묻따',
#  '접수',
#  '보',
#  '18',
#  '육회',
#  '파티',
#  '19',
#  '육퇴후',
#  '20',
#  '토요일',
#  '2탄',
#  '점심',
#  '식',
#  '그릇',
#  '골뱅',
#  '비빔',
#  '21',
#  '22',
#  'ㅡㅡㅡ사진2장',
#  '23',
#  '24',
#  '후라이팬',
#  '이사단이난다역시일요일',
#  '짜파게티',
#  '도',
#  '냄비문제',
#  '25',
#  '야식아니',
#  '저녁밥',
#  '26',
#  '27',
#  '28',
#  '집',
#  '아무것',
#  '안',
#  '교자',
# ...

# %%
all_morphs=okt.morphs(strip_e(str(alldata)))

# %%
all_morphs
# Out:
# ['0',
#  'NaN',
#  '\n',
#  '1',
#  '이쁘고',
#  '비싼',
#  '집사',
#  '주면',
#  '뭐',
#  '하',
#  '나',
#  '코스트코',
#  '에서',
#  '물건',
#  '담아',
#  '온',
#  '만두',
#  '박스',
#  '만',
#  '좋아하는데',
#  '\n',
#  '2',
#  '미나리',
#  ',',
#  '청양',
#  '팍팍',
#  '넣고',
#  '떡',
#  '만',
#  '두',
#  '매운탕',
#  '**',
#  '\n',
#  '3',
#  'NaN',
#  '\n',
#  '4',
#  'NaN',
#  '\n',
#  '5',
#  'NaN',
#  '\n',
#  '6',
#  'NaN',
#  '\n',
#  '7',
#  '--',
#  '토요일',
#  '부터',
#  '나',
#  '없이',
#  '고생',
#  '할',
#  '떠히를',
#  '위해',
#  '8',
#  '직접',
#  '만들었다',
#  '누가',
#  '?',
#  '내',
#  '가',
#  '하하',
#  '하',
#  '오늘',
#  '은',
#  '내',
#  '가',
#  '9',
#  '.',
#  '즐거운',
#  '저녁',
#  '?',
#  '10',
#  '비비고',
#  '왕교',
#  '자',
#  ',',
#  '네모',
#  '군',
#  '만',
#  '두',
#  '밥',
#  '먹긴',
#  '뭐',
#  '하고',
#  '배는',
#  '허전하고',
#  '...',
#  '만두',
#  '나',
#  '굽',
#  '자해',
#  '서',
#  '버터',
#  '어',
#  '...',
#  '\n',
#  '11',
#  'NaN',
#  '\n',
#  '12',
#  '꿀비',
#  '가',
#  '해주는',
#  '오늘',
#  '의',
#  '야식',
#  '13',
#  'NaN',
#  '\n',
#  '14',
#  '불토',
# ...

# %%
count = Counter(all_morphs)

# %%
len(count)
# Out:
# 374
